# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\User\Downloads\Onyx Data - DataDNA Dataset Challenge - Mobile Phone Sales Dataset - May 2025.xlsx")

# %%
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      366 non-null    object
#  1   Transaction_Date    366 non-null    datetime64[ns]
#  2   End of Month        366 non-null    datetime64[ns]
#  3   Mobile_Model        366 non-null    object
#  4   Brand               366 non-null    object
#  5   Storage_Size        366 non-null    object
#  6   Color               366 non-null    object
#  7   Operating_System    366 non-null    object
#  8   Price               366 non-null    int64
#  9   Units_Sold          366 non-null    int64
#  10  Total_Revenue       366 non-null    int64
#  11  Sales_Channel       366 non-null    object
#  12  Payment_Type        366 non-null    object
#  13  Customer_Age        366 non-null    int64
#  14  Customer_Age_Group  366 non-null    object
#  15  Customer_Gender     366 non-null    object
#  16  Country             366 non-null    object
#  17  City                366 non-null    object
#  18  Latitude            366 non-null    float64
#  19  Longitude           366 non-null    float64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(12)
# memory usage: 57.3+ KB

# %%
df.describe()
# Out:
#                     Transaction_Date                   End of Month  \
# count                            366                            366
# mean   2024-07-01 12:00:00.000000256  2024-07-16 06:09:50.163934464
# min              2024-01-01 00:00:00            2024-01-31 00:00:00
# 25%              2024-04-01 06:00:00            2024-04-30 00:00:00
# 50%              2024-07-01 12:00:00            2024-07-31 00:00:00
# 75%              2024-09-30 18:00:00            2024-10-23 06:00:00
# max              2024-12-31 00:00:00            2024-12-31 00:00:00
# std                              NaN                            NaN
#
#              Price  Units_Sold  Total_Revenue  Customer_Age    Latitude  \
# count   366.000000  366.000000     366.000000    366.000000  366.000000
# mean    784.734973   50.677596   39686.920765     38.685792   28.306416
# min     301.000000    1.000000     757.000000     18.000000   12.971600
# 25%     516.500000   28.000000   18428.250000     27.250000   22.356900
# 50%     739.000000   52.500000   32891.500000     38.000000   26.846700
# 75%    1016.000000   73.000000   57614.750000     48.000000   38.419200
# max    1879.000000   99.000000  183150.000000     64.000000   41.008200
# std     373.793362   27.083734   29535.268240     13.019360    9.407334
#
#         Longitude
# count  366.000000
# mean    61.278873
# min     27.128700
# 25%     30.713300
# 50%     73.856700
# 75%     80.270700
# max     91.868700
# std     25.024749

# %%
df.head(4)
# Out:
#                          Transaction_ID Transaction_Date End of Month  \
# 0  3a59ca6b-4f80-443f-9925-c6471b119fc5       2024-01-01   2024-01-31
# 1  45cf6d15-4c86-4367-ada7-cdb67dc97ae2       2024-01-02   2024-01-31
# 2  4053c488-2914-4b4b-add0-8b8ae200f475       2024-01-03   2024-01-31
# 3  fdd350a0-77de-454d-af2d-d1533913542a       2024-01-04   2024-01-31
#
#     Mobile_Model    Brand Storage_Size  Color Operating_System  Price  \
# 0       Pixel 8a   Google        128GB   Blue          Android    534
# 1       Pixel 8a   Google        256GB  White          Android    531
# 2    OnePlus 11R  OnePlus        256GB  Green          Android    608
# 3  Redmi Note 13   Xiaomi        256GB  Green          Android    342
#
#    Units_Sold  Total_Revenue Sales_Channel Payment_Type  Customer_Age  \
# 0          20          10680        Online          UPI            40
# 1          65          34515       Partner         Cash            55
# 2          58          35264        Online          EMI            40
# 3          25           8550        Online  Credit Card            32
#
#   Customer_Age_Group Customer_Gender     Country        City  Latitude  \
# 0              34-41            Male    Pakistan      Lahore   31.5497
# 1              50-57           Other    Pakistan      Multan   30.1575
# 2              34-41          Female  Bangladesh  Chittagong   22.3569
# 3              26-33          Female      Turkey       Bursa   40.1828
#
#    Longitude
# 0    74.3436
# 1    71.5249
# 2    91.7832
# 3    29.0665

# %%
# remove unwanted columns 
df = df.drop(['End of Month', 'Latitude', 'Longitude'], axis =1)
print(df)
# Out:
#                            Transaction_ID Transaction_Date      Mobile_Model  \
# 0    3a59ca6b-4f80-443f-9925-c6471b119fc5       2024-01-01          Pixel 8a
# 1    45cf6d15-4c86-4367-ada7-cdb67dc97ae2       2024-01-02          Pixel 8a
# 2    4053c488-2914-4b4b-add0-8b8ae200f475       2024-01-03       OnePlus 11R
# 3    fdd350a0-77de-454d-af2d-d1533913542a       2024-01-04     Redmi Note 13
# 4    5162e904-aa16-4967-9471-d242b21d3246       2024-01-05          Z Fold 6
# ..                                    ...              ...               ...
# 361  999884f1-17c1-4366-a5e3-8c63f28673dc       2024-12-27    OnePlus 12 Pro
# 362  34a118c4-60d2-4450-8bc1-0c8435adabeb       2024-12-28          Pixel 8a
# 363  f26a4e4f-7e9e-481e-a594-fede2d967ec5       2024-12-29         iPhone 14
# 364  aa4eddb8-b9a3-4f56-89f3-964b0d417867       2024-12-30         iPhone 15
# 365  857e8ec4-6502-4ef5-b95c-c4f249ed055a       2024-12-31  Galaxy S25 Ultra
#
#        Brand Storage_Size  Color Operating_System  Price  Units_Sold  \
# 0     Google        128GB   Blue          Android    534          20
# 1     Google        256GB  White          Android    531          65
# 2    OnePlus        256GB  Green          Android    608          58
# 3     Xiaomi        256GB  Green          Android    342          25
# 4    Samsung        128GB  Black          Android   1841          57
# ..       ...          ...    ...              ...    ...         ...
# 361  OnePlus        256GB   Blue          Android    829          21
# 362   Google         64GB   Blue          Android    539          18
# 363    Apple         64GB   Blue              iOS    884          29
# 364    Apple        256GB  Black              iOS    877          88
# 365  Samsung        128GB    Red          Android   1242          97
#
#      Total_Revenue Sales_Channel Payment_Type  Customer_Age  \
# 0            10680        Online          UPI            40
# 1            34515       Partner         Cash            55
# 2            35264        Online          EMI            40
# 3             8550        Online  Credit Card            32
# 4           104937        Online          UPI            47
# ..             ...           ...          ...           ...
# 361          17409        Online          EMI            19
# 362           9702        Online          EMI            44
# 363          25636  Retail Store         Cash            37
# 364          77176  Retail Store          EMI            61
# 365         120474  Retail Store         Cash            20
#
#     Customer_Age_Group Customer_Gender     Country        City
# 0                34-41            Male    Pakistan      Lahore
# 1                50-57           Other    Pakistan      Multan
# 2                34-41          Female  Bangladesh  Chittagong
# 3                26-33          Female      Turkey       Bursa
# 4                42-49          Female  Bangladesh    Rajshahi
# ..                 ...             ...         ...         ...
# 361              18-25          Female       India     Lucknow
# 362              42-49          Female      Turkey       Izmir
# 363              34-41          Female       India   Ahmedabad
# 364              58-65            Male      Turkey       Bursa
# 365              18-25            Male      Turkey       Izmir
#
# [366 rows x 17 columns]

# %%
df.head()
# Out:
#                          Transaction_ID Transaction_Date   Mobile_Model  \
# 0  3a59ca6b-4f80-443f-9925-c6471b119fc5       2024-01-01       Pixel 8a
# 1  45cf6d15-4c86-4367-ada7-cdb67dc97ae2       2024-01-02       Pixel 8a
# 2  4053c488-2914-4b4b-add0-8b8ae200f475       2024-01-03    OnePlus 11R
# 3  fdd350a0-77de-454d-af2d-d1533913542a       2024-01-04  Redmi Note 13
# 4  5162e904-aa16-4967-9471-d242b21d3246       2024-01-05       Z Fold 6
#
#      Brand Storage_Size  Color Operating_System  Price  Units_Sold  \
# 0   Google        128GB   Blue          Android    534          20
# 1   Google        256GB  White          Android    531          65
# 2  OnePlus        256GB  Green          Android    608          58
# 3   Xiaomi        256GB  Green          Android    342          25
# 4  Samsung        128GB  Black          Android   1841          57
#
#    Total_Revenue Sales_Channel Payment_Type  Customer_Age Customer_Age_Group  \
# 0          10680        Online          UPI            40              34-41
# 1          34515       Partner         Cash            55              50-57
# 2          35264        Online          EMI            40              34-41
# 3           8550        Online  Credit Card            32              26-33
# 4         104937        Online          UPI            47              42-49
#
#   Customer_Gender     Country        City
# 0            Male    Pakistan      Lahore
# 1           Other    Pakistan      Multan
# 2          Female  Bangladesh  Chittagong
# 3          Female      Turkey       Bursa
# 4          Female  Bangladesh    Rajshahi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      366 non-null    object
#  1   Transaction_Date    366 non-null    datetime64[ns]
#  2   Mobile_Model        366 non-null    object
#  3   Brand               366 non-null    object
#  4   Storage_Size        366 non-null    object
#  5   Color               366 non-null    object
#  6   Operating_System    366 non-null    object
#  7   Price               366 non-null    int64
#  8   Units_Sold          366 non-null    int64
#  9   Total_Revenue       366 non-null    int64
#  10  Sales_Channel       366 non-null    object
#  11  Payment_Type        366 non-null    object
#  12  Customer_Age        366 non-null    int64
#  13  Customer_Age_Group  366 non-null    object
#  14  Customer_Gender     366 non-null    object
#  15  Country             366 non-null    object
#  16  City                366 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(12)
# memory usage: 48.7+ KB

# %%
# import libraries for statistical analysis
import scipy.stats as stats
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Calculate Pearson correlation
corr, p_value = stats.pearsonr(df['Total_Revenue'], df['Units_Sold'])

# Print results
print(f"Pearson correlation coefficient: {corr:.4f}")
print(f"P-value: {p_value:.10f}")

if p_value < 0.05:
    print("There is a statistically significant correlation between Revenue and Quantity sold.")
else:
    print("There is no statistically significant correlation between revenue and quantity sold.")

# Plotting with consistent column names
sns.lmplot(x="Units_Sold", y="Total_Revenue", data=df, aspect=1.5)
plt.title(f"Sales vs Quantity (r={corr:.2f})")
plt.show()
# Out:
# Pearson correlation coefficient: 0.7368
# P-value: 0.0000000000
# There is a statistically significant correlation between Revenue and Quantity sold.
